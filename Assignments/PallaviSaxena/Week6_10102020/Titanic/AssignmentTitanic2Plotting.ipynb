# %% [markdown]
# ### Titanic Plotting
# - Load data generated previously from 'titanic_filtered.csv'
# - plot histogram of ages of people
# - plot no of people in each pclass on bar chart
#
#
# - plot a horizontal bar-chart depicting the ratio of males to females
# - plot a bar-chart depicting the ratio of male-survived, female-survived, male-dead, female-dead.
# - plot a stacked bar chart of number of male-survived,dead and female-survived, dead.
# - plot stacked bar of survived with different pclass in same bar.
#
#
# - plot box plot of ages of survived vs not-survived
# - plot scatter plot of ages vs survived.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("titanic_filtered.csv", index_col=0)
titanic.head()
# Out:
#    pclass  survived  gender      age  sibsp  parch    fare embarked
# 0       1         1  female  29.0000      0      0  211.34        S
# 1       1         1    male   0.9167      1      2  151.55        S
# 2       1         0  female   2.0000      1      2  151.55        S
# 3       1         0    male  30.0000      1      2  151.55        S
# 4       1         0  female  25.0000      1      2  151.55        S

# %%
# plot histogram of ages of people

# %%
plt.hist(titanic.age, bins = 20)
# Out:
# (array([ 51.,  21.,  22.,  40., 114., 160., 128., 385.,  97.,  63.,  51.,
#          57.,  38.,  27.,  21.,  19.,   5.,   5.,   2.,   1.]),
#  array([ 0.1667  ,  4.158365,  8.15003 , 12.141695, 16.13336 , 20.125025,
#         24.11669 , 28.108355, 32.10002 , 36.091685, 40.08335 , 44.075015,
#         48.06668 , 52.058345, 56.05001 , 60.041675, 64.03334 , 68.025005,
#         72.01667 , 76.008335, 80.      ]),
#  <a list of 20 Patch objects>)

# %%
fig = plt.figure(figsize=(11.5,4))
axes = fig.add_axes([0,0,1,1])
axes.hist(titanic.age, bins = 20)
# Out:
# (array([ 51.,  21.,  22.,  40., 114., 160., 128., 385.,  97.,  63.,  51.,
#          57.,  38.,  27.,  21.,  19.,   5.,   5.,   2.,   1.]),
#  array([ 0.1667  ,  4.158365,  8.15003 , 12.141695, 16.13336 , 20.125025,
#         24.11669 , 28.108355, 32.10002 , 36.091685, 40.08335 , 44.075015,
#         48.06668 , 52.058345, 56.05001 , 60.041675, 64.03334 , 68.025005,
#         72.01667 , 76.008335, 80.      ]),
#  <a list of 20 Patch objects>)

# %%
#plot no of people in each pclass on bar chart

# %%
'''for n in range(1,len(titanic.pclass.value_counts())+1):
    #.iloc[0].
    plt.bar(titanic.pclass, titanic.pclass.value_counts())'''
titanic['pclass'].value_counts().plot(kind='bar')

# %%
plt.bar(x=titanic.pclass.value_counts().index, height=titanic.pclass.value_counts())
plt.show()

# %%
plt.bar(x=titanic.pclass.value_counts().index, height=titanic.pclass.value_counts(),width=0.4)
plt.xticks(titanic.pclass.value_counts().index, rotation=90)
plt.xlabel("pclass")
plt.show()

# %%
#doubt
mask = titanic.pclass.value_counts()
plt.bar(x=mask.index, height=mask,width=0.4)
plt.xticks(mask.index, rotation=90)
#plt.xticks(mask.index, rotation=90)
#plt.set_xticklabels(mask.index)
plt.xlabel("pclass,pclass")
plt.show()

# %%
# Out:
# [321 277 709]
# Int64Index([1, 2, 3], dtype='int64', name='pclass')

# %%
# plot a bar-chart depicting the ratio of males to females

# %%
plt.bar(x=titanic.gender.value_counts().index, height=titanic.gender.value_counts())
plt.show()

# %%
plt.barh(y=titanic.gender.value_counts().index, width=titanic.gender.value_counts())
plt.show()

# %%
# Out:
# <BarContainer object of 2 artists>

# %%
# plot a bar-chart depicting the ratio of male-survived, female-survived, male-dead, female-dead.

# %%
titanic.groupby(by=["survived"]).gender.value_counts().plot.bar()

# %%
groups = titanic.groupby(['survived','gender']).size()
groups.plot.bar()

# %%
#plt.figure(figsize=(11.5,4))
groups = titanic.groupby(['survived','gender']).size()
groups.plot.bar(width=0.7,color={"green","red","orange","blue"},alpha=0.9,rot=0)

# %%
# Out:
# ('female', 0)
# ('female', 1)
# ('male', 0)
# ('male', 1)

# %%
# plot a stacked bar chart of number of male-survived,dead and female-survived, dead.

# %%
groups = titanic.groupby(['survived','gender']).size()
groups.plot.bar(width=0.5,stacked=True)

# %%
groups = titanic.groupby(['survived']).gender.size()
#plt.bar(df.A.index, df.A.values, width=0.5)
#plt.bar(df.B.index, df.B.values, bottom=df.A.values, width=0.5)
#groups.plot.bar(width=0.8,stacked=True)titanic.gender.value_counts().index, width=titanic.gender.value_counts()
plt.bar(titanic.survived.value_counts().index, titanic.survived.value_counts(), width=0.5)
plt.bar(titanic.gender.value_counts().index, titanic.gender.value_counts(), bottom=titanic.survived.value_counts(), width=0.5)
#plt.bar(df.B.index, df.B.values, bottom=df.A.values, width=0.5)
plt.xticks(titanic.survived.value_counts().index, rotation=0)
plt.show()

# %%
# Out:
# male      682
# female    127
# Name: gender, dtype: int64
# <BarContainer object of 2 artists>

# %%
# plot stacked bar of survived with different pclass in same bar

# %%
# plot box plot of ages of survived vs not-survived

# %%
plt.boxplot([titanic.survived.value_counts().index,titanic.survived.value_counts()])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x280ae670848>,
#   <matplotlib.lines.Line2D at 0x280ae6706c8>,
#   <matplotlib.lines.Line2D at 0x280b0aa36c8>,
#   <matplotlib.lines.Line2D at 0x280b0aa3b48>],
#  'caps': [<matplotlib.lines.Line2D at 0x280ae670c88>,
#   <matplotlib.lines.Line2D at 0x280b0a96d88>,
#   <matplotlib.lines.Line2D at 0x280b0a8bb08>,
#   <matplotlib.lines.Line2D at 0x280b0a8b948>],
#  'boxes': [<matplotlib.lines.Line2D at 0x280b0bbd1c8>,
#   <matplotlib.lines.Line2D at 0x280b0aa5988>],
#  'medians': [<matplotlib.lines.Line2D at 0x280b0a96708>,
#   <matplotlib.lines.Line2D at 0x280b0a8e808>],
#  'fliers': [<matplotlib.lines.Line2D at 0x280b0aa5cc8>,
#   <matplotlib.lines.Line2D at 0x280b0a8ee08>],
#  'means': []}

# %%
f = titanic.age[titanic.survived==1]
m = titanic.age[titanic.survived==0]
plt.boxplot([f,m])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x280b0c45348>,
#   <matplotlib.lines.Line2D at 0x280b0c10348>,
#   <matplotlib.lines.Line2D at 0x280b0c49f08>,
#   <matplotlib.lines.Line2D at 0x280b0c38248>],
#  'caps': [<matplotlib.lines.Line2D at 0x280b0c10108>,
#   <matplotlib.lines.Line2D at 0x280b0c10088>,
#   <matplotlib.lines.Line2D at 0x280b0c1fc48>,
#   <matplotlib.lines.Line2D at 0x280b0c4e908>],
#  'boxes': [<matplotlib.lines.Line2D at 0x280b0c35848>,
#   <matplotlib.lines.Line2D at 0x280b0c38788>],
#  'medians': [<matplotlib.lines.Line2D at 0x280b0c30408>,
#   <matplotlib.lines.Line2D at 0x280b0c56d08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x280b0c38508>,
#   <matplotlib.lines.Line2D at 0x280b0c56288>],
#  'means': []}

# %%
# plot scatter plot of ages vs survived.

# %%
fig = plt.figure(figsize=(11.5,2.5))
axes = fig.add_axes([0,0,1,1])
axes.plot(titanic.age, titanic.survived, "o",alpha=0.3,markersize=4)
