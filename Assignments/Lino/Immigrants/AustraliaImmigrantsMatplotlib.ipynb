# %% [markdown]
# ##### Use AustraliaFiltered.xlsx dataset generated earlier.
#
# - Plot bar chart of total no of immigrants for countires top 5 countires having max no of total immigrants
# - Find total immigrants from each category by area name and plot barchart for each area
# - Plot total immigration trend(immigration of world over the years i.e. year vs Total count for that year) using line plot.
# - Compare Immigration Trend for Asia, Africa and Europe AreaName (Use Line plot).
# - Plot Total Immigrants based on DevelopmenRegion
#
#
# - Plot immigration trend for India using line plot
# - Plot immigration Trend(year vs count) for the coutries with top 5 total immigrants. Use Line plot
# - For the above use area plot with alpha = 0.5
#
#
# - Compare Immigration Trend for top-5 countires using stacked area plot

# %%
# Plot bar chart of total no of immigrants for countries top 5 countires having max no of total immigrants
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel('AustraliaFiltered_LM.xlsx', index_col=0)
df.head()
# Out:
#             Country AreaName           Region             DevName  1980  1981  \
# 224     Afghanistan     Asia    Southern Asia  Developing regions    10    20
# 225         Albania   Europe  Southern Europe   Developed regions     0     0
# 226         Algeria   Africa  Northern Africa  Developing regions    10    50
# 227  American Samoa  Oceania        Polynesia  Developing regions     0     0
# 228         Andorra   Europe  Southern Europe   Developed regions     0     0
#
#      1982  1983  1984  1985  ...  2000  2001  2002  2003  2004  2005  2006  \
# 224    30    30    70   100  ...   100    20    40    70    80   110   180
# 225     0     0     0     0  ...   110   110   200   250   140   130   110
# 226    30    10    20    20  ...    20    30    60    20    20    50    30
# 227     0     0     0    20  ...     0     0     0     0     0     0     0
# 228    10     0     0     0  ...     0    10    10     0    10    10     0
#
#      2007  2008  Total
# 224   140   560   4630
# 225   110   140   1910
# 226    30    60    730
# 227     0    10     30
# 228    10    10    100
#
# [5 rows x 34 columns]

# %%
plt.subplots(figsize=(20,5))
df.Total.plot(kind='bar')

# %%
df[['Country', 'Total']].sort_values(by='Total').tail()
# Out:
#                                                Country    Total
# 265                                              China   387180
# 266     China, Hong Kong Special Administrative Region   388640
# 434                           United States of America   450370
# 367                                        New Zealand   898760
# 432  United Kingdom of Great Britain and Northern I...  1333340

# %%
df[['Country', 'Total']].sort_values(by='Total').tail().plot(kind='bar',x='Country',y='Total',rot=0,figsize=(20,5))

# %%
# Find total immigrants from each category by area name and plot barchart for each area
df.groupby('AreaName')['Total'].sum()
# Out:
# AreaName
# Africa                              354440
# Asia                               3463640
# Europe                             2166780
# Latin America and the Caribbean     120350
# Northern America                    592060
# Oceania                            1126180
# Name: Total, dtype: int64

# %%
plt.subplots(figsize=(20,5))
plt.xlabel("AreaName", fontdict={'size':16})
plt.ylabel("Total immigrants in Millions", fontdict={'size':16})
plt.xticks(fontsize=12)
df.groupby('AreaName')['Total'].sum().plot(kind='bar',rot=0)

# %% [markdown]
# # Plot total immigration trend(immigration of world over the years i.e. year vs Total count for that year) using line plot.

# %%
print(df.columns)
# Out:
# Index(['Country', 'AreaName', 'Region', 'DevName', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        'Total'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 34

# %%
df.columns[4:33]
# Out:
# Index(['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008'],
#       dtype='object')

# %%
print([df[i].sum() for i in df.columns[4:33]])
# Out:
# [180230, 208250, 191190, 150350, 149560, 167940, 191310, 215100, 247500, 232690, 228910, 230300, 212670, 190780, 216640, 249600, 256990, 257290, 264990, 287020, 312060, 351320, 359830, 386690, 349340, 361670, 399890, 442340, 531000]

# %%
plt.subplots(figsize=(20,5))
plt.xlabel("year", fontdict={'size':16})
plt.ylabel("Total count", fontdict={'size':16})
plt.plot(df.columns[4:33],[df[i].sum() for i in df.columns[4:33]],marker='o')

# %%
# Compare Immigration Trend for Asia, Africa and Europe AreaName (Use Line plot).
df[df.AreaName=='Asia'].sum(numeric_only=True)[:-1]  # omitting last column 'Total', hence [:-1] is applied
# Out:
# 1980     45030
# 1981     49250
# 1982     46190
# 1983     50930
# 1984     55850
# 1985     56090
# 1986     61910
# 1987     75460
# 1988     87340
# 1989     88650
# 1990     99930
# 1991    112570
# 1992    103490
# 1993     86680
# 1994     96700
# 1995    114780
# 1996    119990
# 1997    117300
# 1998    116150
# 1999    120460
# 2000    134620
# 2001    164010
# 2002    184830
# 2003    194800
# 2004    166160
# 2005    172550
# 2006    202410
# 2007    239900
# 2008    299610
# dtype: int64

# %%
plt.subplots(figsize=(20,5))
plt.xlabel("year", fontdict={'size':16})
plt.ylabel("Total count", fontdict={'size':16})

plt.plot(df.columns[4:33],df[df.AreaName=='Asia'].sum(numeric_only=True)[:-1],marker='o', label ='Asia')
plt.plot(df.columns[4:33],df[df.AreaName=='Africa'].sum(numeric_only=True)[:-1],marker='o', label ='Africa')
plt.plot(df.columns[4:33],df[df.AreaName=='Europe'].sum(numeric_only=True)[:-1],marker='o', label ='Europe')
plt.legend()

# %%
# Plot Total Immigrants based on DevelopmenRegion
df.groupby('DevName')['Total'].sum()
# Out:
# DevName
# Developed regions     3927800
# Developing regions    3895650
# Name: Total, dtype: int64

# %%
# just confirming the Total count, since both counts are too close
df[df['DevName']=='Developed regions']['Total'].sum(), df[df['DevName']=='Developing regions']['Total'].sum()
# Out:
# (3927800, 3895650)

# %%
plt.ylabel("Total count in millions", fontdict={'size':16})
df.groupby('DevName')['Total'].sum().plot(kind='bar', rot=0)

# %%
print(list(range(1980,2009)))
# Out:
# [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008]

# %%
 print(list(map(str, range(1980,2009)))) # map(func, *iterables) -> computes the function using arguments from each of the iterables
# Out:
# ['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008']

# %%
# Plot immigration trend for India using line plot
plt.subplots(figsize=(20,5))
plt.xlabel("year", fontdict={'size':16})
plt.ylabel("Total count", fontdict={'size':16})

plt.plot(df.columns[4:33],df[df.Country=='India'].iloc[0,4:33], marker='o')

# %%
df[df.Country=='India'].iloc[0,4:33]
# Out:
# 1980     1220
# 1981     1560
# 1982     1870
# 1983     2090
# 1984     2300
# 1985     2510
# 1986     2390
# 1987     2900
# 1988     2990
# 1989     2980
# 1990     3930
# 1991     6080
# 1992     5450
# 1993     3350
# 1994     4570
# 1995     6420
# 1996     5780
# 1997     6410
# 1998     7810
# 1999     8370
# 2000    10390
# 2001     9380
# 2002     9240
# 2003    15080
# 2004    18310
# 2005    19920
# 2006    27880
# 2007    41920
# 2008    58400
# Name: 319, dtype: object

# %% [markdown]
# # Plot immigration Trend(year vs count) for the coutries with top 5 total immigrants. Use Line plot

# %%
for i in df[['Country', 'Total']].sort_values(by='Total').tail().Country:
    print(df[df.Country==i])
# Out:
#     Country AreaName        Region             DevName  1980  1981  1982  \
# 265   China     Asia  Eastern Asia  Developing regions   860   870   560
#
#      1983  1984  1985  ...   2000   2001   2002   2003   2004   2005   2006  \
# 265   580  1220  2190  ...  16700  22220  29000  33410  29860  28820  32190
#
#       2007   2008   Total
# 265  42920  54300  387180
#
# [1 rows x 34 columns]
#                                             Country AreaName        Region  \
# 266  China, Hong Kong Special Administrative Region     Asia  Eastern Asia
#
#                 DevName  1980  1981  1982  1983  1984  1985  ...   2000  \
# 266  Developing regions  4170  4380  4980  5480  7450  6820  ...  16410
#
#       2001   2002   2003  2004   2005   2006  2007   2008   Total
# 266  18620  20200  19220  9740  10070  10270  9680  11030  388640
#
# [1 rows x 34 columns]
#                       Country          AreaName            Region  \
# 434  United States of America  Northern America  Northern America
#
#                DevName   1980   1981   1982   1983   1984   1985  ...   2000  \
# 434  Developed regions  10470  12080  12490  11110  11840  12480  ...  18030
#
#       2001   2002   2003   2004   2005   2006   2007   2008   Total
# 434  19230  18950  18980  18540  18490  17320  19260  20860  450370
#
# [1 rows x 34 columns]
#          Country AreaName                     Region            DevName  \
# 367  New Zealand  Oceania  Australia and New Zealand  Developed regions
#
#       1980   1981   1982   1983   1984   1985  ...   2000   2001   2002  \
# 367  34370  34440  23920  13620  16900  27070  ...  47230  45570  29500
#
#       2003   2004   2005   2006   2007   2008   Total
# 367  28000  40710  44680  45550  39120  46960  898760
#
# [1 rows x 34 columns]
#                                                Country AreaName  \
# 432  United Kingdom of Great Britain and Northern I...   Europe
#
#               Region            DevName   1980   1981   1982   1983   1984  \
# 432  Northern Europe  Developed regions  43540  57050  51730  31660  25150
#
#       1985  ...   2000   2001   2002   2003   2004   2005   2006   2007  \
# 432  27630  ...  51000  52940  57330  70150  53140  53300  57250  61490
#
#       2008    Total
# 432  65160  1333340
#
# [1 rows x 34 columns]

# %%
df[df.Country=='China']
# Out:
#     Country AreaName        Region             DevName  1980  1981  1982  \
# 265   China     Asia  Eastern Asia  Developing regions   860   870   560
#
#      1983  1984  1985  ...   2000   2001   2002   2003   2004   2005   2006  \
# 265   580  1220  2190  ...  16700  22220  29000  33410  29860  28820  32190
#
#       2007   2008   Total
# 265  42920  54300  387180
#
# [1 rows x 34 columns]

# %%
df[df.Country=='China'].iloc[:,4:33].T
# Out:
#         265
# 1980    860
# 1981    870
# 1982    560
# 1983    580
# 1984   1220
# 1985   2190
# 1986   1820
# 1987   2070
# 1988   2810
# 1989   4220
# 1990   3430
# 1991   8400
# 1992   6880
# 1993   4610
# 1994   4400
# 1995   8550
# 1996  12450
# 1997   8460
# 1998  10310
# 1999  13070
# 2000  16700
# 2001  22220
# 2002  29000
# 2003  33410
# 2004  29860
# 2005  28820
# 2006  32190
# 2007  42920
# 2008  54300

# %%
df.columns[4:33]
# Out:
# Index(['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008'],
#       dtype='object')

# %%
plt.subplots(figsize=(16,5))

for i in df[['Country', 'Total']].sort_values(by='Total').tail().Country:
    plt.plot(df[df.Country==i].iloc[:,4:33].T, marker='o', label=i)   

plt.xlabel("year", fontdict={'size':16})
plt.ylabel("Total count", fontdict={'size':16})
plt.legend()

# %%
# Plot immigration Trend(year vs count) for the coutries with top 5 total immigrants.
# For the above, use area plot with alpha = 0.5
df.sort_values(by='Total').tail().Country
# Out:
# 265                                                China
# 266       China, Hong Kong Special Administrative Region
# 434                             United States of America
# 367                                          New Zealand
# 432    United Kingdom of Great Britain and Northern I...
# Name: Country, dtype: object

# %%
df1 = pd.DataFrame(df.sort_values(by='Total').tail().iloc[:,4:33].T)
df1.columns=df.sort_values(by='Total').tail().Country

# %%
df.loc[df.Total.sort_values().tail().index].iloc[:,4:33]
# Out:
#       1980   1981   1982   1983   1984   1985   1986   1987   1988   1989  \
